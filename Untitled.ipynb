# %%
import pandas as pd
import plotly.express as px

# Load the CSV data into pandas DataFrames
ame_df = pd.read_csv('ame_cash.csv')
ftv_df = pd.read_csv('ftv_cash.csv')
rop_df = pd.read_csv('rop_cash.csv')

# %%
ftv_df
# Out:
#        date  symbol  reportedCurrency      cik  fillingDate   acceptedDate  \
# 0  12/31/23     FTV               USD  1659166      2/27/24  2/27/24 16:48
# 1  12/31/22     FTV               USD  1659166      2/28/23  2/28/23 16:13
# 2  12/31/21     FTV               USD  1659166       3/1/22  2/28/22 20:47
# 3  12/31/20     FTV               USD  1659166      2/26/21  2/26/21 16:03
# 4  12/31/19     FTV               USD  1659166      2/27/20  2/27/20 17:09
#
#     calendarYear  period          netIncome  depreciationAndAmortization  ...  \
# 0           2023      FY    $865,800,000.00              $456,800,000.00  ...
# 1           2022      FY    $755,200,000.00              $465,600,000.00  ...
# 2           2021      FY    $614,200,000.00              $395,500,000.00  ...
# 3           2020      FY  $1,452,200,000.00              $384,000,000.00  ...
# 4           2019      FY    $725,400,000.00              $426,200,000.00  ...
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                            $32,299,999.00             -$10,900,000.00
# 1                        -$1,273,000,000.00             -$37,800,000.00
# 2                           $652,000,000.00              -$3,000,000.00
# 3                          -$696,100,000.00              $27,400,000.00
# 4                         $2,802,900,000.00               $7,100,000.00
#
#       netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0   $1,179,600,000.00  $1,888,800,000.00          $709,200,000.00
# 1    -$110,100,000.00    $709,200,000.00          $819,300,000.00
# 2  -$1,005,500,000.00    $819,300,000.00        $1,824,800,000.00
# 3     $619,600,000.00  $1,824,800,000.00        $1,205,200,000.00
# 4      $26,800,000.00  $1,205,200,000.00        $1,178,400,000.00
#
#    operatingCashFlow  capitalExpenditure       freeCashFlow  \
# 0  $1,353,600,000.00    -$107,800,000.00  $1,245,800,000.00
# 1  $1,303,200,000.00     -$95,800,000.00  $1,207,400,000.00
# 2    $961,100,000.00     -$50,000,000.00    $911,100,000.00
# 3  $1,436,700,000.00     -$75,700,000.00  $1,361,000,000.00
# 4  $1,271,400,000.00    -$112,500,000.00  $1,158,900,000.00
#
#                                                 link  \
# 0  https://www.sec.gov/Archives/edgar/data/165916...
# 1  https://www.sec.gov/Archives/edgar/data/165916...
# 2  https://www.sec.gov/Archives/edgar/data/165916...
# 3  https://www.sec.gov/Archives/edgar/data/165916...
# 4  https://www.sec.gov/Archives/edgar/data/165916...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/165916...
# 1  https://www.sec.gov/Archives/edgar/data/165916...
# 2  https://www.sec.gov/Archives/edgar/data/165916...
# 3  https://www.sec.gov/Archives/edgar/data/165916...
# 4  https://www.sec.gov/Archives/edgar/data/165916...
#
# [5 rows x 40 columns]

# %%
import pandas as pd

# Load the CSV data into pandas DataFrames
ame_df = pd.read_csv('ame_cash.csv')
ftv_df = pd.read_csv('ftv_cash.csv')
rop_df = pd.read_csv('rop_cash.csv')

# Remove whitespaces from column names
ame_df.columns = ame_df.columns.str.replace(' ', '')
ftv_df.columns = ftv_df.columns.str.replace(' ', '')
rop_df.columns = rop_df.columns.str.replace(' ', '')


# List of columns to convert to numeric
numeric_cols = ['netIncome', 'depreciationAndAmortization', 'deferredIncomeTax', 'stockBasedCompensation',
                'changeInWorkingCapital', 'accountsReceivables', 'inventory', 'accountsPayables',
                'otherWorkingCapital', 'otherNonCashItems', 'netCashProvidedByOperatingActivities',
                'investmentsInPropertyPlantAndEquipment', 'acquisitionsNet', 'purchasesOfInvestments',
                'salesMaturitiesOfInvestments', 'otherInvestingActivites', 'netCashUsedForInvestingActivites',
                'debtRepayment', 'commonStockIssued', 'commonStockRepurchased', 'dividendsPaid',
                'otherFinancingActivites', 'netCashUsedProvidedByFinancingActivities', 'effectOfForexChangesOnCash',
                'netChangeInCash', 'cashAtEndOfPeriod', 'cashAtBeginningOfPeriod', 'operatingCashFlow',
                'capitalExpenditure', 'freeCashFlow']

# Convert columns to numeric with error handling
for df in [ame_df, ftv_df, rop_df]:
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Print the updated data types
print("AME Data Types:")
print(ame_df.dtypes)
print("\nFTV Data Types:")
print(ftv_df.dtypes)
print("\nROP Data Types:")
print(rop_df.dtypes)
# Out:
# AME Data Types:
# date                                        object
# symbol                                      object
# reportedCurrency                            object
# cik                                          int64
# fillingDate                                 object
# acceptedDate                                object
# calendarYear                                 int64
# period                                      object
# netIncome                                    int64
# depreciationAndAmortization                  int64
# deferredIncomeTax                            int64
# stockBasedCompensation                       int64
# changeInWorkingCapital                       int64
# accountsReceivables                          int64
# inventory                                    int64
# accountsPayables                             int64
# otherWorkingCapital                          int64
# otherNonCashItems                            int64
# netCashProvidedByOperatingActivities         int64
# investmentsInPropertyPlantAndEquipment       int64
# acquisitionsNet                              int64
# purchasesOfInvestments                       int64
# salesMaturitiesOfInvestments                 int64
# otherInvestingActivites                      int64
# netCashUsedForInvestingActivites             int64
# debtRepayment                                int64
# commonStockIssued                            int64
# commonStockRepurchased                       int64
# dividendsPaid                                int64
# otherFinancingActivites                      int64
# netCashUsedProvidedByFinancingActivities     int64
# effectOfForexChangesOnCash                   int64
# netChangeInCash                              int64
# cashAtEndOfPeriod                            int64
# cashAtBeginningOfPeriod                      int64
# operatingCashFlow                            int64
# capitalExpenditure                           int64
# freeCashFlow                                 int64
# link                                        object
# finalLink                                   object
# dtype: object
#
# FTV Data Types:
# date                                         object
# symbol                                       object
# reportedCurrency                             object
# cik                                           int64
# fillingDate                                  object
# acceptedDate                                 object
# calendarYear                                  int64
# period                                       object
# netIncome                                   float64
# depreciationAndAmortization                 float64
# deferredIncomeTax                           float64
# stockBasedCompensation                      float64
# changeInWorkingCapital                      float64
# accountsReceivables                         float64
# inventory                                   float64
# accountsPayables                            float64
# otherWorkingCapital                         float64
# otherNonCashItems                           float64
# netCashProvidedByOperatingActivities        float64
# investmentsInPropertyPlantAndEquipment      float64
# acquisitionsNet                             float64
# purchasesOfInvestments                      float64
# salesMaturitiesOfInvestments                float64
# otherInvestingActivites                     float64
# netCashUsedForInvestingActivites            float64
# debtRepayment                               float64
# commonStockIssued                           float64
# commonStockRepurchased                      float64
# dividendsPaid                               float64
# otherFinancingActivites                     float64
# netCashUsedProvidedByFinancingActivities    float64
# effectOfForexChangesOnCash                  float64
# netChangeInCash                             float64
# cashAtEndOfPeriod                           float64
# cashAtBeginningOfPeriod                     float64
# operatingCashFlow                           float64
# capitalExpenditure                          float64
# freeCashFlow                                float64
# link                                         object
# finalLink                                    object
# dtype: object
#
# ROP Data Types:
# date                                         object
# symbol                                       object
# reportedCurrency                              int64
# cik                                          object
# fillingDate                                  object
# acceptedDate                                  int64
# calendarYear                                 object
# period                                        int64
# netIncome                                     int64
# depreciationAndAmortization                   int64
# deferredIncomeTax                             int64
# stockBasedCompensation                        int64
# changeInWorkingCapital                        int64
# accountsReceivables                           int64
# inventory                                     int64
# accountsPayables                              int64
# otherWorkingCapital                           int64
# otherNonCashItems                             int64
# netCashProvidedByOperatingActivities          int64
# investmentsInPropertyPlantAndEquipment        int64
# acquisitionsNet                               int64
# purchasesOfInvestments                        int64
# salesMaturitiesOfInvestments                  int64
# otherInvestingActivites                       int64
# netCashUsedForInvestingActivites              int64
# debtRepayment                                 int64
# commonStockIssued                             int64
# commonStockRepurchased                        int64
# dividendsPaid                                 int64
# otherFinancingActivites                       int64
# netCashUsedProvidedByFinancingActivities      int64
# effectOfForexChangesOnCash                    int64
# netChangeInCash                               int64
# cashAtEndOfPeriod                             int64
# cashAtBeginningOfPeriod                       int64
# operatingCashFlow                             int64
# capitalExpenditure                            int64
# freeCashFlow                                float64
# link                                         object
# finalLink                                   float64
# dtype: object

# %%
rop_df.head()
# Out:
#            date symbol  reportedCurrency         cik          fillingDate  \
# 2023-12-31  ROP    USD            882835  2024-02-22  2024-02-22 17:05:32
# 2022-12-31  ROP    USD            882835  2023-02-27  2023-02-27 16:48:06
# 2021-12-31  ROP    USD            882835  2022-02-22  2022-02-22 17:02:07
# 2020-12-31  ROP    USD            882835  2021-02-22  2021-02-22 08:59:47
# 2019-12-31  ROP    USD            882835  2020-02-28  2020-02-28 14:02:08
#
#             acceptedDate calendarYear      period  netIncome  \
# 2023-12-31          2023           FY  1368400000  755200000
# 2022-12-31          2022           FY   985600000  650100000
# 2021-12-31          2021           FY   982600000  634100000
# 2020-12-31          2020           FY   949700000  520800000
# 2019-12-31          2019           FY  1767900000  416000000
#
#             depreciationAndAmortization  ...  \
# 2023-12-31                    374700000  ...
# 2022-12-31                    296400000  ...
# 2021-12-31                    282900000  ...
# 2020-12-31                    259600000  ...
# 2019-12-31                   -726700000  ...
#
#             netCashUsedProvidedByFinancingActivities  \
# 2023-12-31                                  12200000
# 2022-12-31                                 -37500000
# 2021-12-31                                 -12300000
# 2020-12-31                                  10500000
# 2019-12-31                                   2500000
#
#             effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 2023-12-31                  -578500000        214300000          792800000
# 2022-12-31                   441300000        792800000          351500000
# 2021-12-31                    43200000        351500000          308300000
# 2020-12-31                  -401400000        308300000          709700000
# 2019-12-31                   345300000        709700000          364400000
#
#             cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 2023-12-31               2035100000         -108000000          1927100000
# 2022-12-31                734600000          -70300000           664300000
# 2021-12-31               2011900000          -62600000          1949300000
# 2020-12-31               1525100000          -48900000          1476200000
# 2019-12-31               1461800000          -62900000          1398900000
#
#             freeCashFlow                                               link  \
# 2023-12-31           NaN  https://www.sec.gov/Archives/edgar/data/882835...
# 2022-12-31           NaN  https://www.sec.gov/Archives/edgar/data/882835...
# 2021-12-31           NaN  https://www.sec.gov/Archives/edgar/data/882835...
# 2020-12-31           NaN  https://www.sec.gov/Archives/edgar/data/882835...
# 2019-12-31           NaN  https://www.sec.gov/Archives/edgar/data/882835...
#
#             finalLink
# 2023-12-31        NaN
# 2022-12-31        NaN
# 2021-12-31        NaN
# 2020-12-31        NaN
# 2019-12-31        NaN
#
# [5 rows x 40 columns]
